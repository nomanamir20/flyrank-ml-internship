# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/nomanamir20/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## My Lane: Freestyle
#
# I chose a freestyle research lane focused on helping SEO managers prioritize webpages for content improvement. Instead of simply predicting whether a webpage will decline, I want to support a real business decision: deciding which pages should be reviewed first when time and resources are limited.
#
# The goal is to build a ranking system that helps SEO teams identify webpages that are most likely to benefit from updates based on historical search performance signals. This approach supports better decision-making and allows teams to focus on the pages with the highest potential impact.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ### Research Question
# Which webpages should SEO managers prioritize for content updates so they can improve search performance while making the best use of limited time and resources?
#
# ### Unit of Analysis
#
# The unit of analysis is a single webpage (content item). Each row in the dataset represents one webpage, and the model will produce a priority score for each page.
#
# ### Decision
# The decision is to identify which webpages should be prioritized for SEO improvements before their search performance declines.
#
# ### Who Takes the Action?
# SEO managers and content editors will use the results to decide which webpages should be reviewed and updated first.
#
# ### Action
# The selected webpages can be improved by updating content, improving titles, optimizing keywords, adding internal links, or refreshing outdated information.
#
# ### Cost of a Wrong Recommendation
# If an important webpage is not identified, it may continue losing search traffic, reducing visibility and potential business opportunities. If a healthy webpage is incorrectly prioritized, the SEO team may spend valuable time and resources on unnecessary updates.
#
# ### Why Machine Learning?
# A website may contain hundreds or thousands of webpages, making manual analysis difficult. Machine learning can combine many performance signals to rank webpages based on their likelihood of benefiting from optimization, helping teams make better decisions.
#
# ### Output
#
# The output of this project will be a ranked list (priority score) of webpages that should be reviewed first by SEO managers.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Quick Look at the Data
#
# The starter dataset contains **30,000 content items** collected from **32 different clients**, providing a diverse set of webpages for analysis.
#
# Most of the dataset consists of **keyword articles (27,207)**, while **feedly articles (2,096)** and **comparison articles (697)** make up smaller portions. This suggests that keyword-focused content is the primary content type available for analysis.
#
# The trend distribution also shows that **16,262 webpages are classified as "down"**, compared with **5,962 stable** pages and **4,388 up** pages. This indicates that a large number of webpages experience declining performance, making webpage prioritization an important business problem that could benefit from data-driven decision support.

# %%
import pandas as pd

# Load the starter dataset
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# Basic information
print("Dataset Shape:", df.shape)

print("\nNumber of Unique Clients:")
print(df["client_id"].nunique())

print("\nContent Types:")
print(df["content_type"].value_counts())

print("\nTrend Direction:")
print(df["trend_direction"].value_counts())
# Out:
# Dataset Shape: (30000, 44)
#
# Number of Unique Clients:
# 32
#
# Content Types:
# content_type
# keyword article       27207
# feedly article         2096
# comparison article      697
# Name: count, dtype: int64
#
# Trend Direction:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64

# %% [markdown]
# ## Careful Words
# This project is intended to provide decision-support for SEO managers by identifying webpages that may deserve priority for content improvement based on historical performance signals.
#
# The analysis can identify observed patterns and relationships within the available dataset, but it cannot prove that one factor directly causes another. It also cannot predict or explain Google's ranking algorithm.
#
# The results should be used as decision-support to help prioritize pages for manual review, rather than as an automatic replacement for human judgment.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
