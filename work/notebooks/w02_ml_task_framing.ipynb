# %% [markdown]
# <a href="https://colab.research.google.com/github/nomanamir20/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/nomanamir20/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## My Lane as an ML Task (Type)
#
# ### Task Type: Ranking / Scoring
#
# My project is a **ranking (scoring)** machine learning task. Instead of predicting a simple yes/no outcome, the goal is to assign a priority score to each webpage so that SEO managers can rank pages from highest to lowest priority for content improvement.
#
# This ranking helps SEO teams decide which webpages should be reviewed first when time and resources are limited. A ranked list is more useful than a simple classification because it allows teams to focus on the pages with the greatest potential impact.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Target or Proxy
#
# The target of this project is a **priority score** that ranks webpages according to how urgently they should be reviewed for SEO improvements.
#
# Since the starter dataset does not contain a direct "priority" label, this score acts as a **proxy** based on observed historical performance signals. The project is intended to support decision-making rather than make automatic decisions.
#
# The ranking is designed to help SEO managers identify webpages that are most likely to benefit from updates. It should be treated as decision-support rather than proof that a webpage will definitely improve or decline.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Success Metric
#
# The primary success metric for this project is **Precision@K**.
#
# Since the goal is to rank webpages by priority, Precision@K measures how many of the top-ranked webpages truly deserve attention. A higher Precision@K means that SEO managers spend their limited time reviewing the most valuable pages first.
#
# This metric matches the business objective because the team is usually interested in reviewing only a limited number of webpages rather than the entire website.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import pandas as pd

# Load the starter dataset
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# Select only keyword articles for our SEO lane
lane_df = df[df["content_type"] == "keyword article"]

print("Unit of Analysis:")
print("One row = One webpage (content item)\n")

print("Lane Dataset Shape:")
print(lane_df.shape)

print("\nSample of the data:")
display(lane_df.head(10))
# Out:
# Unit of Analysis:
# One row = One webpage (content item)
#
# Lane Dataset Shape:
# (27207, 44)
#
# Sample of the data:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
# 5  content_d4084a4bc775  client_f369cb89fc          720.0         1.00
# 6  content_9a34b442b552  client_8722616204            0.0         0.00
# 7  content_a63219c6e95a  client_19581e27de          590.0         0.44
# 8  content_5e6c160719bc  client_6208ef0f77            0.0         0.00
# 9  content_c27558df2b0c  client_19581e27de            0.0         0.00
#
# ...

# %% [markdown]
# ## Why ML Beats a Fixed Rule Here
#
# A fixed rule, such as selecting webpages only because they have a low CTR or a poor average position, is too simple for this problem. A webpage's performance depends on many factors working together, including search volume, competition, content length, engagement rate, scroll rate, and average position.
#
# Machine learning can analyse all of these signals together and identify patterns that are difficult to capture with a single rule or threshold. Instead of relying on one condition, it can assign a priority score to each webpage based on the combined effect of multiple features.
#
# This project is intended to provide **decision-support** for SEO managers by helping them prioritise webpages for review. The model supports human decision-making and does not replace human judgement.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
